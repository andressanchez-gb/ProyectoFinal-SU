# %% [markdown]
# <a href="https://colab.research.google.com/github/andressanchez-gb/ProyectoFinal-SU/blob/Banca_Seguros_Pagos_Masivos/ProyectoFinal_SU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine

DATABASE_URL = "postgresql://postgres.uyecvaskgaqtjymeswkp:1A*23456ssASñ@aws-0-ca-central-1.pooler.supabase.com:6543/postgres"
#"postgresql://postgres:1A*23456ssASñ@db.uyecvaskgaqtjymeswkp.supabase.co:6544/postgres"

#Ajuste Robert
engine = create_engine(DATABASE_URL)
df = pd.read_sql("select * from sabana_polizas_emasivos LIMIT 5", engine)
df.head()
# Out:
#    id_emasivo id_cliente       asegurado fecha_emision         ramo  \
# 0           1      CLI-1  Asegurado EM 1    2026-01-02  Desgravamen
# 1           2      CLI-2  Asegurado EM 2    2026-01-03  Desgravamen
# 2           3      CLI-3  Asegurado EM 3    2026-01-04  Desgravamen
# 3           4      CLI-4  Asegurado EM 4    2026-01-05  Desgravamen
# 4           5      CLI-5  Asegurado EM 5    2026-01-06  Desgravamen
#
#       producto    sucursal primer_apellido segundo_apellido    nombres  \
# 0  Vida Segura  Sucursal 1         P_Ape 1          S_Ape 1  Nombres 1
# 1  Vida Segura  Sucursal 2         P_Ape 2          S_Ape 2  Nombres 2
# 2  Vida Segura  Sucursal 3         P_Ape 3          S_Ape 3  Nombres 3
# 3  Vida Segura  Sucursal 4         P_Ape 4          S_Ape 4  Nombres 4
# 4  Vida Segura  Sucursal 0         P_Ape 5          S_Ape 5  Nombres 5
#
#    prima_neta
# 0       13.99
# 1      171.56
# 2      145.49
# 3       74.43
# 4      200.60
